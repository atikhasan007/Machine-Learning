# %% [markdown]
# <a href="https://colab.research.google.com/github/atikhasan007/Machine-Learning/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mdrifaturrahman33/levir-cd")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/mdrifaturrahman33/levir-cd?dataset_version_number=1...
# 100%|██████████| 2.30G/2.30G [00:29<00:00, 83.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/mdrifaturrahman33/levir-cd/versions/1

# %%
import os
import cv2
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import albumentations as A
from albumentations.pytorch import ToTensorV2

class LEVIRCDDataset(Dataset):
    def __init__(self, images_dir, transform=None):
        self.images_dir_b = os.path.join(images_dir, 'B')  # Pre-change
        self.images_dir_a = os.path.join(images_dir, 'A')  # Post-change
        self.masks_dir = os.path.join(images_dir, 'label')
        self.transform = transform

        # Ensure consistent ordering of files
        self.images_b = sorted(f for f in os.listdir(self.images_dir_b) if f.endswith(('.png', '.jpg', '.jpeg')))
        self.images_a = sorted(f for f in os.listdir(self.images_dir_a) if f.endswith(('.png', '.jpg', '.jpeg')))
        self.masks = sorted(f for f in os.listdir(self.masks_dir) if f.endswith(('.png', '.jpg', '.jpeg')))

    def __len__(self):
        return len(self.images_b)

    def __getitem__(self, idx):
        img_path_b = os.path.join(self.images_dir_b, self.images_b[idx])  # Pre-change
        img_path_a = os.path.join(self.images_dir_a, self.images_a[idx])  # Post-change
        mask_path = os.path.join(self.masks_dir, self.masks[idx])

        # Load images
        image_b = cv2.imread(img_path_b, cv2.IMREAD_COLOR)  # BGR
        image_b = cv2.cvtColor(image_b, cv2.COLOR_BGR2RGB)  # RGB
        image_b = image_b.astype(np.float32) / 255.0  # Normalize to [0, 1]

        image_a = cv2.imread(img_path_a, cv2.IMREAD_COLOR)  # BGR
        image_a = cv2.cvtColor(image_a, cv2.COLOR_BGR2RGB)  # RGB
        image_a = image_a.astype(np.float32) / 255.0  # Normalize to [0, 1]

        # Load mask
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)  # Grayscale
        mask = mask.astype(np.float32) / 255.0  # Normalize to [0, 1]

        # Apply transformations consistently
        if self.transform:
            augmented = self.transform(image=image_b, image1=image_a, mask=mask)  # Pre-change first
            image_b = augmented['image']  # Pre-change
            image_a = augmented['image1']  # Post-change
            mask = augmented['mask']  # Mask

        # Convert mask to tensor and add channel dimension
        # Ensure mask is a tensor and normalize
        # if isinstance(mask, np.ndarray):  # If Albumentations outputs a NumPy array
        #     mask = torch.from_numpy(mask).float().unsqueeze(0) / 255.0
        # elif isinstance(mask, torch.Tensor):  # If Albumentations outputs a PyTorch tensor
        mask = mask.unsqueeze(0)

        return image_b, image_a, mask


# Albumentations transformations
train_transform = A.Compose([
    A.Resize(height=256, width=256),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    # A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
    ToTensorV2(),
], additional_targets={'image1': 'image'})  # Specify additional target for post-change image

val_transform = A.Compose([
    A.Resize(height=256, width=256),
    # A.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
    ToTensorV2(),
], additional_targets={'image1': 'image'})  # Specify additional target for post-change image

# Datasets
LEVIR_train_dataset = LEVIRCDDataset(
    images_dir="/root/.cache/kagglehub/datasets/mdrifaturrahman33/levir-cd/versions/1/LEVIR CD/train",
    transform=train_transform
)

LEVIR_val_dataset = LEVIRCDDataset(
    images_dir="/root/.cache/kagglehub/datasets/mdrifaturrahman33/levir-cd/versions/1/LEVIR CD/val",
    transform=val_transform
)

LEVIR_test_dataset = LEVIRCDDataset(
    images_dir="/root/.cache/kagglehub/datasets/mdrifaturrahman33/levir-cd/versions/1/LEVIR CD/test",
    transform=val_transform
)

# Dataloaders
LEVIR_train_loader = DataLoader(LEVIR_train_dataset, batch_size=16, shuffle=True)
LEVIR_val_loader = DataLoader(LEVIR_val_dataset, batch_size=16, shuffle=False)
LEVIR_test_loader = DataLoader(LEVIR_test_dataset, batch_size=16, shuffle=False)

# %%
print(f'Training Dataset Length: {len(LEVIR_train_dataset)}')
print(f'Validation Dataset Length: {len(LEVIR_val_dataset)}')
print(f'Testing Dataset Length: {len(LEVIR_test_dataset)}')
# Out:
# Training Dataset Length: 445
# Validation Dataset Length: 64
# Testing Dataset Length: 128

# %%
import cv2
import numpy as np
import torch

'''Image=cv2.imread("/kaggle/input/massachusetts-buildings-dataset/png/train/22678915_15.png")
Mask=image=cv2.imread("/kaggle/input/massachusetts-buildings-dataset/png/train_labels/22678915_15.png")

print(f'Original mask shape:{Image.shape}')

print(f'Original mask shape:{Mask.shape}')'''

#print(np.unique(Mask))

image1, image2, mask = LEVIR_train_dataset[10]

print(f'Transformed Image shape:{image1.shape}')
print(f'Transformed Image shape:{image2.shape}')
print(f'Transformed mask shape:{mask.shape}')

print(torch.unique(mask))
print(torch.unique(image1))
print(torch.unique(image2))

print(torch.unique(mask).numel())
# Out:
# Transformed Image shape:torch.Size([3, 256, 256])
# Transformed Image shape:torch.Size([3, 256, 256])
# Transformed mask shape:torch.Size([1, 256, 256])
# tensor([0., 1.])
# tensor([0.0137, 0.0157, 0.0176,  ..., 0.9971, 0.9980, 1.0000])
# tensor([0.0000e+00, 9.8039e-04, 1.9608e-03,  ..., 9.9804e-01, 9.9902e-01,
#         1.0000e+00])
# 2

# %%
import matplotlib.pyplot as plt

# Set up the plot size and remove axes
plt.figure(figsize=(10, 10))  # Set the figure size to be larger

for i in range(3):
    image1, image2, mask = LEVIR_train_dataset[i]

    # Plot Image 1
    plt.subplot(3, 3, i+1)
    plt.imshow(image1.permute(1, 2, 0),cmap='gray')  # Convert tensor to HWC format
    plt.axis('off')  # Remove axes for a cleaner view

    # Plot Image 2
    plt.subplot(3, 3, 3+i+1)
    plt.imshow(image2.permute(1, 2, 0),cmap='gray')  # Convert tensor to HWC format
    plt.axis('off')  # Remove axes

    # Plot Mask
    plt.subplot(3, 3, 6+i+1)
    plt.imshow(mask.permute(1, 2, 0), cmap='gray')  # Display in grayscale
    plt.axis('off')  # Remove axes

plt.show()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# Basic ConvBlock used in both encoder and decoder
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ConvBlock, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        return x

# Encoder block: consists of two convolutions followed by max-pooling
class EncoderBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(EncoderBlock, self).__init__()
        self.conv1 = ConvBlock(in_channels, out_channels)
        self.conv2 = ConvBlock(out_channels, out_channels)
        self.pool = nn.MaxPool2d(2)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        p = self.pool(x)
        return x, p  # Return both the feature map and pooled result

# Decoder block: uses a transposed convolution (upsampling), followed by convolutions
class DecoderBlock(nn.Module):
    def __init__(self, in_channels, skip_channels, out_channels):
        super(DecoderBlock, self).__init__()
        self.upconv = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2)
        self.conv1 = ConvBlock(in_channels + skip_channels, out_channels)  # Account for concatenation
        self.conv2 = ConvBlock(out_channels, out_channels)

    def forward(self, x, skip):
        x = self.upconv(x)
        x = torch.cat([x, skip], dim=1)  # Concatenate along the channel dimension
        x = self.conv1(x)
        x = self.conv2(x)
        return x

# The main combined Encoder Siamese U-Net architecture
class SiameseUNet(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(SiameseUNet, self).__init__()

        # Encoder blocks for image 1
        self.encoder1a = EncoderBlock(in_channels, 64)
        self.encoder2a = EncoderBlock(64, 128)
        self.encoder3a = EncoderBlock(128, 256)
        self.encoder4a = EncoderBlock(256, 512)

        # Encoder blocks for image 2
        self.encoder1b = EncoderBlock(in_channels, 64)
        self.encoder2b = EncoderBlock(64, 128)
        self.encoder3b = EncoderBlock(128, 256)
        self.encoder4b = EncoderBlock(256, 512)

        # Bottleneck
        self.bottleneck = ConvBlock(1024, 1024)  # 512 + 512 from both encoders

        # Decoder block (shared between both images)
        self.decoder4 = DecoderBlock(1024, 512, 512)
        self.decoder3 = DecoderBlock(512, 256, 256)
        self.decoder2 = DecoderBlock(256, 128, 128)
        self.decoder1 = DecoderBlock(128, 64, 64)

        # Final convolution to output the segmentation map
        self.final_conv = nn.Conv2d(64, out_channels, kernel_size=1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x1, x2):
        # Encoder part for image 1
        e1a, p1a = self.encoder1a(x1)
        e2a, p2a = self.encoder2a(p1a)
        e3a, p3a = self.encoder3a(p2a)
        e4a, p4a = self.encoder4a(p3a)

        # Encoder part for image 2
        e1b, p1b = self.encoder1b(x2)
        e2b, p2b = self.encoder2b(p1b)
        e3b, p3b = self.encoder3b(p2b)
        e4b, p4b = self.encoder4b(p3b)

        # Concatenate the encoder outputs from both images (for each layer)
        concat_e4 = torch.cat([e4a, e4b], dim=1)  # Concatenate along the channel dimension
        concat_e3 = torch.cat([e3a, e3b], dim=1)
        concat_e2 = torch.cat([e2a, e2b], dim=1)
        concat_e1 = torch.cat([e1a, e1b], dim=1)

        # Bottleneck
        b = self.bottleneck(torch.cat([p4a, p4b], dim=1))

        # Decoder part (shared across both images)
        d4 = self.decoder4(b, concat_e4)
        d3 = self.decoder3(d4, concat_e3)
        d2 = self.decoder2(d3, concat_e2)
        d1 = self.decoder1(d2, concat_e1)

        # Final output
        out = self.sigmoid(self.final_conv(d1))
        return out


x1 = torch.randn(1, 3, 256, 256)  # Example image 1
x2 = torch.randn(1, 3, 256, 256)  # Example image 2

# Instantiate the Siamese U-Net model
siamese_unet = SiameseUNet(in_channels=3, out_channels=1)

# Get the output
output = siamese_unet(x1, x2)

print("Output shape:", output.shape)
# Out:
# Output shape: torch.Size([1, 1, 256, 256])

# %%
import torch
import torch.nn as nn
import torch.optim as optim

def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=60, device='cuda'):
    model.to(device)

    for epoch in range(num_epochs):
        model.train()
        running_train_loss = 0.0
        train_iou_sum = 0
        train_acc_sum = 0
        train_precision_sum = 0
        train_recall_sum = 0
        train_dice_sum = 0
        train_samples = 0

        for inputs1, inputs2, labels in train_loader:  # Change: Get two input images
            inputs1, inputs2, labels = inputs1.to(device), inputs2.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs1, inputs2)  # Forward pass with two inputs
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_train_loss += loss.item() * inputs1.size(0)
            acc, precision, recall, dice, iou = calculate_metrics(outputs, labels)
            train_acc_sum += acc * inputs1.size(0)
            train_precision_sum += precision * inputs1.size(0)
            train_recall_sum += recall * inputs1.size(0)
            train_dice_sum += dice * inputs1.size(0)
            train_iou_sum += iou * inputs1.size(0)
            train_samples += inputs1.size(0)

        epoch_train_loss = running_train_loss / train_samples
        epoch_train_iou = train_iou_sum / train_samples
        epoch_train_acc = train_acc_sum / train_samples
        epoch_train_precision = train_precision_sum / train_samples
        epoch_train_recall = train_recall_sum / train_samples
        epoch_train_dice = train_dice_sum / train_samples

        model.eval()
        running_val_loss = 0.0
        val_iou_sum = 0
        val_acc_sum = 0
        val_precision_sum = 0
        val_recall_sum = 0
        val_dice_sum = 0
        val_samples = 0

        with torch.no_grad():
            for inputs1, inputs2, labels in val_loader:  # Change: Get two input images
                inputs1, inputs2, labels = inputs1.to(device), inputs2.to(device), labels.to(device)
                outputs = model(inputs1, inputs2)  # Forward pass with two inputs
                loss = criterion(outputs, labels)

                running_val_loss += loss.item() * inputs1.size(0)
                acc, precision, recall, dice, iou = calculate_metrics(outputs, labels)
                val_acc_sum += acc * inputs1.size(0)
                val_precision_sum += precision * inputs1.size(0)
                val_recall_sum += recall * inputs1.size(0)
                val_dice_sum += dice * inputs1.size(0)
                val_iou_sum += iou * inputs1.size(0)
                val_samples += inputs1.size(0)

        epoch_val_loss = running_val_loss / val_samples
        epoch_val_iou = val_iou_sum / val_samples
        epoch_val_acc = val_acc_sum / val_samples
        epoch_val_precision = val_precision_sum / val_samples
        epoch_val_recall = val_recall_sum / val_samples
        epoch_val_dice = val_dice_sum / val_samples

        print(f'Epoch {epoch+1}/{num_epochs} | '
              f'Train Loss: {epoch_train_loss:.4f}, Val Loss: {epoch_val_loss:.4f} | '
              f'Train IoU: {epoch_train_iou:.4f}, Val IoU: {epoch_val_iou:.4f} | '
              f'Train Acc: {epoch_train_acc:.4f}, Val Acc: {epoch_val_acc:.4f} | '
              f'Train Precision: {epoch_train_precision:.4f}, Val Precision: {epoch_val_precision:.4f} | '
              f'Train Recall: {epoch_train_recall:.4f}, Val Recall: {epoch_val_recall:.4f} | '
              f'Train Dice: {epoch_train_dice:.4f}, Val Dice: {epoch_val_dice:.4f}')

     # Save the final model
    torch.save(model.state_dict(), 'model.pt')

def calculate_metrics(outputs, labels, threshold=0.5):
    predictions = (outputs > threshold).float()
    labels = labels.float()

    tp = torch.sum(predictions * labels)
    tn = torch.sum((1 - predictions) * (1 - labels))
    fp = torch.sum(predictions * (1 - labels))
    fn = torch.sum((1 - predictions) * labels)

    precision = tp / (tp + fp + 1e-6)
    recall = tp / (tp + fn + 1e-6)
    dice = 2 * tp / (2 * tp + fp + fn + 1e-6)

    # IoU
    iou = tp / (tp + fp + fn + 1e-6)

    # Accuracy
    accuracy = (tp + tn) / (tp + tn + fp + fn + 1e-6)

    return accuracy.item(), precision.item(), recall.item(), dice.item(), iou.item()

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Initialize your model
model = SiameseUNet(in_channels=3, out_channels=1).to(device)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Train the model with the updated loop
train_model(model, LEVIR_train_loader, LEVIR_val_loader, criterion, optimizer, num_epochs=100, device=device)

# Load the saved model for future use (optional)
#loaded_model = SiameseUNet(in_channels=3, out_channels=1).to(device)
#loaded_model.load_state_dict(torch.load('model.pt'))
#loaded_model.eval()  # Set to evaluation mode for prediction
# Out:
# Epoch 1/100 | Train Loss: 0.5388, Val Loss: 0.4340 | Train IoU: 0.1858, Val IoU: 0.0000 | Train Acc: 0.8653, Val Acc: 0.9580 | Train Precision: 0.2293, Val Precision: 0.0000 | Train Recall: 0.5801, Val Recall: 0.0000 | Train Dice: 0.3081, Val Dice: 0.0000
# Epoch 2/100 | Train Loss: 0.3871, Val Loss: 0.3687 | Train IoU: 0.3155, Val IoU: 0.1543 | Train Acc: 0.9528, Val Acc: 0.9617 | Train Precision: 0.4926, Val Precision: 0.7151 | Train Recall: 0.4802, Val Recall: 0.1668 | Train Dice: 0.4775, Val Dice: 0.2622
# Epoch 3/100 | Train Loss: 0.3427, Val Loss: 0.3203 | Train IoU: 0.3604, Val IoU: 0.3859 | Train Acc: 0.9585, Val Acc: 0.9659 | Train Precision: 0.5498, Val Precision: 0.6260 | Train Recall: 0.5245, Val Recall: 0.5259 | Train Dice: 0.5269, Val Dice: 0.5501
# Epoch 4/100 | Train Loss: 0.3141, Val Loss: 0.9406 | Train IoU: 0.4000, Val IoU: 0.1395 | Train Acc: 0.9617, Val Acc: 0.9208 | Train Precision: 0.5902, Val Precision: 0.2078 | Train Recall: 0.5652, Val Recall: 0.3260 | Train Dice: 0.5692, Val Dice: 0.2448
# Epoch 5/100 | Train Loss: 0.2922, Val Loss: 0.2764 | Train IoU: 0.4215, Val IoU: 0.4345 | Train Acc: 0.9631, Val Acc: 0.9684 | Train Precision: 0.5974, Val Precision: 0.6453 | Train Recall: 0.5973, Val Recall: 0.5901 | Train Dice: 0.5897, Val Dice: 0.6030
# Epoch 6/100 | Train Loss: 0.2740, Val Loss: 0.2558 | Train IoU: 0.4426, Val IoU: 0.3948 | Train Acc: 0.9650, Val Acc: 0.9700 | Train Precision: 0.6174, Val Precision: 0.7631 | Train Recall: 0.6280, Val Recall: 0.4575 | Train Dice: 0.6113, Val Dice: 0.5573
# Epoch 7/100 | Train Loss: 0.2608, Val Loss: 0.3318 | Train IoU: 0.4687, Val IoU: 0.4928 | Train Acc: 0.9680, Val Acc: 0.9690 | Train Precision: 0.6575, Val Precision: 0.6104 | Train Recall: 0.6288, Val Recall: 0.7251 | Train Dice: 0.6369, Val Dice: 0.6599
# Epoch 8/100 | Train Loss: 0.2491, Val Loss: 0.2270 | Train IoU: 0.4621, Val IoU: 0.4636 | Train Acc: 0.9667, Val Acc: 0.9733 | Train Precision: 0.6365, Val Precision: 0.7770 | Train Recall: 0.6468, Val Recall: 0.5355 | Train Dice: 0.6288, Val Dice: 0.6309
# Epoch 9/100 | Train Loss: 0.2327, Val Loss: 0.2647 | Train IoU: 0.5017, Val IoU: 0.5194 | Train Acc: 0.9704, Val Acc: 0.9713 | Train Precision: 0.6851, Val Precision: 0.6358 | Train Recall: 0.6579, Val Recall: 0.7444 | Train Dice: 0.6667, Val Dice: 0.6836
# Epoch 10/100 | Train Loss: 0.2254, Val Loss: 0.2247 | Train IoU: 0.4919, Val IoU: 0.5211 | Train Acc: 0.9706, Val Acc: 0.9745 | Train Precision: 0.6836, Val Precision: 0.7297 | Train Recall: 0.6544, Val Recall: 0.6452 | Train Dice: 0.6570, Val Dice: 0.6843
# Epoch 11/100 | Train Loss: 0.2158, Val Loss: 0.2063 | Train IoU: 0.5050, Val IoU: 0.5495 | Train Acc: 0.9715, Val Acc: 0.9738 | Train Precision: 0.6993, Val Precision: 0.6765 | Train Recall: 0.6603, Val Recall: 0.7454 | Train Dice: 0.6682, Val Dice: 0.7086
# Epoch 12/100 | Train Loss: 0.2057, Val Loss: 0.2087 | Train IoU: 0.5210, Val IoU: 0.4771 | Train Acc: 0.9714, Val Acc: 0.9747 | Train Precision: 0.6898, Val Precision: 0.8179 | Train Recall: 0.6896, Val Recall: 0.5345 | Train Dice: 0.6834, Val Dice: 0.6433
# Epoch 13/100 | Train Loss: 0.1973, Val Loss: 0.2060 | Train IoU: 0.5274, Val IoU: 0.5540 | Train Acc: 0.9732, Val Acc: 0.9756 | Train Precision: 0.7338, Val Precision: 0.7083 | Train Recall: 0.6608, Val Recall: 0.7224 | Train Dice: 0.6894, Val Dice: 0.7126
# Epoch 14/100 | Train Loss: 0.1880, Val Loss: 0.1951 | Train IoU: 0.5442, Val IoU: 0.5485 | Train Acc: 0.9740, Val Acc: 0.9759 | Train Precision: 0.7212, Val Precision: 0.7327 | Train Recall: 0.7006, Val Recall: 0.6870 | Train Dice: 0.7038, Val Dice: 0.7074
# Epoch 15/100 | Train Loss: 0.1794, Val Loss: 0.1684 | Train IoU: 0.5634, Val IoU: 0.5819 | Train Acc: 0.9754, Val Acc: 0.9789 | Train Precision: 0.7457, Val Precision: 0.7956 | Train Recall: 0.7040, Val Recall: 0.6847 | Train Dice: 0.7197, Val Dice: 0.7348
# Epoch 16/100 | Train Loss: 0.1747, Val Loss: 0.1759 | Train IoU: 0.5559, Val IoU: 0.5665 | Train Acc: 0.9750, Val Acc: 0.9762 | Train Precision: 0.7403, Val Precision: 0.7125 | Train Recall: 0.7002, Val Recall: 0.7367 | Train Dice: 0.7135, Val Dice: 0.7230
# Epoch 17/100 | Train Loss: 0.1687, Val Loss: 0.1540 | Train IoU: 0.5541, Val IoU: 0.5881 | Train Acc: 0.9749, Val Acc: 0.9778 | Train Precision: 0.7396, Val Precision: 0.7486 | Train Recall: 0.6977, Val Recall: 0.7319 | Train Dice: 0.7121, Val Dice: 0.7400
# Epoch 18/100 | Train Loss: 0.1589, Val Loss: 0.1545 | Train IoU: 0.5762, Val IoU: 0.5141 | Train Acc: 0.9761, Val Acc: 0.9762 | Train Precision: 0.7490, Val Precision: 0.8136 | Train Recall: 0.7216, Val Recall: 0.5826 | Train Dice: 0.7300, Val Dice: 0.6769
# Epoch 19/100 | Train Loss: 0.1545, Val Loss: 0.1550 | Train IoU: 0.5791, Val IoU: 0.5257 | Train Acc: 0.9765, Val Acc: 0.9772 | Train Precision: 0.7587, Val Precision: 0.8431 | Train Recall: 0.7154, Val Recall: 0.5856 | Train Dice: 0.7324, Val Dice: 0.6861
# Epoch 20/100 | Train Loss: 0.1480, Val Loss: 0.1394 | Train IoU: 0.5828, Val IoU: 0.5857 | Train Acc: 0.9769, Val Acc: 0.9791 | Train Precision: 0.7734, Val Precision: 0.7986 | Train Recall: 0.7087, Val Recall: 0.6885 | Train Dice: 0.7358, Val Dice: 0.7375
# Epoch 21/100 | Train Loss: 0.1425, Val Loss: 0.1327 | Train IoU: 0.5886, Val IoU: 0.5993 | Train Acc: 0.9775, Val Acc: 0.9802 | Train Precision: 0.7741, Val Precision: 0.8306 | Train Recall: 0.7166, Val Recall: 0.6820 | Train Dice: 0.7402, Val Dice: 0.7485
# Epoch 22/100 | Train Loss: 0.1387, Val Loss: 0.1245 | Train IoU: 0.5823, Val IoU: 0.6310 | Train Acc: 0.9772, Val Acc: 0.9811 | Train Precision: 0.7619, Val Precision: 0.8053 | Train Recall: 0.7206, Val Recall: 0.7438 | Train Dice: 0.7343, Val Dice: 0.7730
# Epoch 23/100 | Train Loss: 0.1319, Val Loss: 0.1414 | Train IoU: 0.6040, Val IoU: 0.6188 | Train Acc: 0.9784, Val Acc: 0.9806 | Train Precision: 0.7784, Val Precision: 0.7962 | Train Recall: 0.7350, Val Recall: 0.7345 | Train Dice: 0.7525, Val Dice: 0.7640
# Epoch 24/100 | Train Loss: 0.1284, Val Loss: 0.1261 | Train IoU: 0.6009, Val IoU: 0.6044 | Train Acc: 0.9786, Val Acc: 0.9794 | Train Precision: 0.7921, Val Precision: 0.7848 | Train Recall: 0.7207, Val Recall: 0.7240 | Train Dice: 0.7495, Val Dice: 0.7522
# Epoch 25/100 | Train Loss: 0.1246, Val Loss: 0.1227 | Train IoU: 0.6024, Val IoU: 0.6204 | Train Acc: 0.9784, Val Acc: 0.9819 | Train Precision: 0.7680, Val Precision: 0.8614 | Train Recall: 0.7455, Val Recall: 0.6884 | Train Dice: 0.7506, Val Dice: 0.7652
# Epoch 26/100 | Train Loss: 0.1228, Val Loss: 0.1159 | Train IoU: 0.5940, Val IoU: 0.6397 | Train Acc: 0.9781, Val Acc: 0.9814 | Train Precision: 0.7880, Val Precision: 0.7958 | Train Recall: 0.7200, Val Recall: 0.7647 | Train Dice: 0.7428, Val Dice: 0.7797
# Epoch 27/100 | Train Loss: 0.1162, Val Loss: 0.1098 | Train IoU: 0.6237, Val IoU: 0.6340 | Train Acc: 0.9795, Val Acc: 0.9816 | Train Precision: 0.7885, Val Precision: 0.8211 | Train Recall: 0.7536, Val Recall: 0.7357 | Train Dice: 0.7675, Val Dice: 0.7749
# Epoch 28/100 | Train Loss: 0.1117, Val Loss: 0.1054 | Train IoU: 0.6295, Val IoU: 0.6447 | Train Acc: 0.9801, Val Acc: 0.9823 | Train Precision: 0.8059, Val Precision: 0.8257 | Train Recall: 0.7444, Val Recall: 0.7459 | Train Dice: 0.7720, Val Dice: 0.7832
# Epoch 29/100 | Train Loss: 0.1082, Val Loss: 0.1043 | Train IoU: 0.6345, Val IoU: 0.6473 | Train Acc: 0.9802, Val Acc: 0.9811 | Train Precision: 0.8011, Val Precision: 0.7779 | Train Recall: 0.7590, Val Recall: 0.7934 | Train Dice: 0.7760, Val Dice: 0.7853
# Epoch 30/100 | Train Loss: 0.1050, Val Loss: 0.1091 | Train IoU: 0.6390, Val IoU: 0.6374 | Train Acc: 0.9806, Val Acc: 0.9813 | Train Precision: 0.8096, Val Precision: 0.7874 | Train Recall: 0.7565, Val Recall: 0.7704 | Train Dice: 0.7791, Val Dice: 0.7781
# Epoch 31/100 | Train Loss: 0.1035, Val Loss: 0.1000 | Train IoU: 0.6324, Val IoU: 0.6542 | Train Acc: 0.9802, Val Acc: 0.9823 | Train Precision: 0.8079, Val Precision: 0.8021 | Train Recall: 0.7544, Val Recall: 0.7793 | Train Dice: 0.7741, Val Dice: 0.7905
# Epoch 32/100 | Train Loss: 0.1006, Val Loss: 0.0912 | Train IoU: 0.6391, Val IoU: 0.6451 | Train Acc: 0.9805, Val Acc: 0.9831 | Train Precision: 0.8019, Val Precision: 0.8740 | Train Recall: 0.7654, Val Recall: 0.7103 | Train Dice: 0.7789, Val Dice: 0.7836
# Epoch 33/100 | Train Loss: 0.0996, Val Loss: 0.0952 | Train IoU: 0.6235, Val IoU: 0.6668 | Train Acc: 0.9801, Val Acc: 0.9830 | Train Precision: 0.7970, Val Precision: 0.8088 | Train Recall: 0.7494, Val Recall: 0.7913 | Train Dice: 0.7668, Val Dice: 0.7995
# Epoch 34/100 | Train Loss: 0.0938, Val Loss: 0.0965 | Train IoU: 0.6513, Val IoU: 0.6753 | Train Acc: 0.9815, Val Acc: 0.9832 | Train Precision: 0.8153, Val Precision: 0.7999 | Train Recall: 0.7676, Val Recall: 0.8119 | Train Dice: 0.7883, Val Dice: 0.8057
# Epoch 35/100 | Train Loss: 0.0910, Val Loss: 0.0944 | Train IoU: 0.6634, Val IoU: 0.6426 | Train Acc: 0.9820, Val Acc: 0.9811 | Train Precision: 0.8238, Val Precision: 0.7658 | Train Recall: 0.7752, Val Recall: 0.7998 | Train Dice: 0.7973, Val Dice: 0.7823
# Epoch 36/100 | Train Loss: 0.0887, Val Loss: 0.0874 | Train IoU: 0.6636, Val IoU: 0.6524 | Train Acc: 0.9821, Val Acc: 0.9828 | Train Precision: 0.8222, Val Precision: 0.8303 | Train Recall: 0.7791, Val Recall: 0.7533 | Train Dice: 0.7975, Val Dice: 0.7890
# Epoch 37/100 | Train Loss: 0.0887, Val Loss: 0.0866 | Train IoU: 0.6483, Val IoU: 0.6656 | Train Acc: 0.9814, Val Acc: 0.9818 | Train Precision: 0.8122, Val Precision: 0.7663 | Train Recall: 0.7726, Val Recall: 0.8358 | Train Dice: 0.7857, Val Dice: 0.7989
# Epoch 38/100 | Train Loss: 0.0857, Val Loss: 0.0848 | Train IoU: 0.6588, Val IoU: 0.6720 | Train Acc: 0.9821, Val Acc: 0.9840 | Train Precision: 0.8177, Val Precision: 0.8444 | Train Recall: 0.7747, Val Recall: 0.7668 | Train Dice: 0.7936, Val Dice: 0.8034
# Epoch 39/100 | Train Loss: 0.0838, Val Loss: 0.0793 | Train IoU: 0.6590, Val IoU: 0.6705 | Train Acc: 0.9821, Val Acc: 0.9840 | Train Precision: 0.8233, Val Precision: 0.8561 | Train Recall: 0.7716, Val Recall: 0.7551 | Train Dice: 0.7936, Val Dice: 0.8024
# Epoch 40/100 | Train Loss: 0.0806, Val Loss: 0.0742 | Train IoU: 0.6747, Val IoU: 0.6867 | Train Acc: 0.9828, Val Acc: 0.9847 | Train Precision: 0.8293, Val Precision: 0.8539 | Train Recall: 0.7851, Val Recall: 0.7774 | Train Dice: 0.8054, Val Dice: 0.8138
# Epoch 41/100 | Train Loss: 0.0790, Val Loss: 0.0735 | Train IoU: 0.6760, Val IoU: 0.6917 | Train Acc: 0.9830, Val Acc: 0.9847 | Train Precision: 0.8356, Val Precision: 0.8358 | Train Recall: 0.7822, Val Recall: 0.8004 | Train Dice: 0.8063, Val Dice: 0.8173
# Epoch 42/100 | Train Loss: 0.0771, Val Loss: 0.0721 | Train IoU: 0.6776, Val IoU: 0.6887 | Train Acc: 0.9830, Val Acc: 0.9844 | Train Precision: 0.8331, Val Precision: 0.8354 | Train Recall: 0.7873, Val Recall: 0.7964 | Train Dice: 0.8075, Val Dice: 0.8152
# Epoch 43/100 | Train Loss: 0.0766, Val Loss: 0.0755 | Train IoU: 0.6710, Val IoU: 0.6383 | Train Acc: 0.9827, Val Acc: 0.9832 | Train Precision: 0.8204, Val Precision: 0.8978 | Train Recall: 0.7910, Val Recall: 0.6875 | Train Dice: 0.8024, Val Dice: 0.7786
# Epoch 44/100 | Train Loss: 0.0743, Val Loss: 0.0697 | Train IoU: 0.6787, Val IoU: 0.6974 | Train Acc: 0.9832, Val Acc: 0.9853 | Train Precision: 0.8376, Val Precision: 0.8515 | Train Recall: 0.7846, Val Recall: 0.7941 | Train Dice: 0.8081, Val Dice: 0.8215
# Epoch 45/100 | Train Loss: 0.0720, Val Loss: 0.0698 | Train IoU: 0.6897, Val IoU: 0.6704 | Train Acc: 0.9837, Val Acc: 0.9844 | Train Precision: 0.8357, Val Precision: 0.8898 | Train Recall: 0.7999, Val Recall: 0.7315 | Train Dice: 0.8161, Val Dice: 0.8017
# Epoch 46/100 | Train Loss: 0.0697, Val Loss: 0.0684 | Train IoU: 0.6954, Val IoU: 0.6882 | Train Acc: 0.9842, Val Acc: 0.9844 | Train Precision: 0.8509, Val Precision: 0.8356 | Train Recall: 0.7935, Val Recall: 0.7950 | Train Dice: 0.8201, Val Dice: 0.8147
# Epoch 47/100 | Train Loss: 0.0700, Val Loss: 0.0669 | Train IoU: 0.6865, Val IoU: 0.6796 | Train Acc: 0.9835, Val Acc: 0.9842 | Train Precision: 0.8335, Val Precision: 0.8435 | Train Recall: 0.7993, Val Recall: 0.7772 | Train Dice: 0.8139, Val Dice: 0.8087
# Epoch 48/100 | Train Loss: 0.0682, Val Loss: 0.0659 | Train IoU: 0.6915, Val IoU: 0.6898 | Train Acc: 0.9839, Val Acc: 0.9848 | Train Precision: 0.8439, Val Precision: 0.8564 | Train Recall: 0.7953, Val Recall: 0.7796 | Train Dice: 0.8174, Val Dice: 0.8159
# Epoch 49/100 | Train Loss: 0.0664, Val Loss: 0.0639 | Train IoU: 0.6969, Val IoU: 0.6903 | Train Acc: 0.9843, Val Acc: 0.9849 | Train Precision: 0.8470, Val Precision: 0.8464 | Train Recall: 0.7978, Val Recall: 0.7890 | Train Dice: 0.8208, Val Dice: 0.8165
# Epoch 50/100 | Train Loss: 0.0660, Val Loss: 0.0646 | Train IoU: 0.6915, Val IoU: 0.6906 | Train Acc: 0.9841, Val Acc: 0.9845 | Train Precision: 0.8394, Val Precision: 0.8256 | Train Recall: 0.7996, Val Recall: 0.8088 | Train Dice: 0.8170, Val Dice: 0.8167
# Epoch 51/100 | Train Loss: 0.0649, Val Loss: 0.0629 | Train IoU: 0.6945, Val IoU: 0.6945 | Train Acc: 0.9841, Val Acc: 0.9853 | Train Precision: 0.8424, Val Precision: 0.8711 | Train Recall: 0.8009, Val Recall: 0.7737 | Train Dice: 0.8195, Val Dice: 0.8192
# Epoch 52/100 | Train Loss: 0.0623, Val Loss: 0.0632 | Train IoU: 0.7071, Val IoU: 0.6914 | Train Acc: 0.9848, Val Acc: 0.9846 | Train Precision: 0.8518, Val Precision: 0.8403 | Train Recall: 0.8072, Val Recall: 0.7956 | Train Dice: 0.8281, Val Dice: 0.8171
# Epoch 53/100 | Train Loss: 0.0618, Val Loss: 0.0620 | Train IoU: 0.7088, Val IoU: 0.7005 | Train Acc: 0.9848, Val Acc: 0.9852 | Train Precision: 0.8503, Val Precision: 0.8471 | Train Recall: 0.8112, Val Recall: 0.8016 | Train Dice: 0.8292, Val Dice: 0.8235
# Epoch 54/100 | Train Loss: 0.0601, Val Loss: 0.0605 | Train IoU: 0.7130, Val IoU: 0.7015 | Train Acc: 0.9851, Val Acc: 0.9855 | Train Precision: 0.8565, Val Precision: 0.8675 | Train Recall: 0.8110, Val Recall: 0.7852 | Train Dice: 0.8322, Val Dice: 0.8241
# Epoch 55/100 | Train Loss: 0.0607, Val Loss: 0.0596 | Train IoU: 0.7013, Val IoU: 0.6946 | Train Acc: 0.9846, Val Acc: 0.9840 | Train Precision: 0.8527, Val Precision: 0.8038 | Train Recall: 0.7995, Val Recall: 0.8372 | Train Dice: 0.8240, Val Dice: 0.8194
# Epoch 56/100 | Train Loss: 0.0615, Val Loss: 0.0597 | Train IoU: 0.6915, Val IoU: 0.7024 | Train Acc: 0.9839, Val Acc: 0.9847 | Train Precision: 0.8395, Val Precision: 0.8103 | Train Recall: 0.8013, Val Recall: 0.8415 | Train Dice: 0.8171, Val Dice: 0.8249
# Epoch 57/100 | Train Loss: 0.0585, Val Loss: 0.0582 | Train IoU: 0.7111, Val IoU: 0.6900 | Train Acc: 0.9849, Val Acc: 0.9854 | Train Precision: 0.8484, Val Precision: 0.8956 | Train Recall: 0.8170, Val Recall: 0.7506 | Train Dice: 0.8309, Val Dice: 0.8159
# Epoch 58/100 | Train Loss: 0.0578, Val Loss: 0.0567 | Train IoU: 0.7091, Val IoU: 0.7005 | Train Acc: 0.9849, Val Acc: 0.9853 | Train Precision: 0.8532, Val Precision: 0.8612 | Train Recall: 0.8100, Val Recall: 0.7891 | Train Dice: 0.8295, Val Dice: 0.8234
# Epoch 59/100 | Train Loss: 0.0572, Val Loss: 0.0574 | Train IoU: 0.7062, Val IoU: 0.6856 | Train Acc: 0.9849, Val Acc: 0.9848 | Train Precision: 0.8508, Val Precision: 0.8708 | Train Recall: 0.8072, Val Recall: 0.7632 | Train Dice: 0.8273, Val Dice: 0.8126
# Epoch 60/100 | Train Loss: 0.0565, Val Loss: 0.0583 | Train IoU: 0.7084, Val IoU: 0.6894 | Train Acc: 0.9849, Val Acc: 0.9848 | Train Precision: 0.8530, Val Precision: 0.8550 | Train Recall: 0.8094, Val Recall: 0.7802 | Train Dice: 0.8290, Val Dice: 0.8156
# Epoch 61/100 | Train Loss: 0.0556, Val Loss: 0.0593 | Train IoU: 0.7118, Val IoU: 0.6907 | Train Acc: 0.9851, Val Acc: 0.9849 | Train Precision: 0.8549, Val Precision: 0.8529 | Train Recall: 0.8110, Val Recall: 0.7838 | Train Dice: 0.8313, Val Dice: 0.8165
# Epoch 62/100 | Train Loss: 0.0545, Val Loss: 0.0594 | Train IoU: 0.7138, Val IoU: 0.6888 | Train Acc: 0.9852, Val Acc: 0.9834 | Train Precision: 0.8589, Val Precision: 0.7718 | Train Recall: 0.8091, Val Recall: 0.8648 | Train Dice: 0.8327, Val Dice: 0.8155
# Epoch 63/100 | Train Loss: 0.0542, Val Loss: 0.0520 | Train IoU: 0.7138, Val IoU: 0.7166 | Train Acc: 0.9851, Val Acc: 0.9863 | Train Precision: 0.8503, Val Precision: 0.8668 | Train Recall: 0.8183, Val Recall: 0.8056 | Train Dice: 0.8326, Val Dice: 0.8345
# Epoch 64/100 | Train Loss: 0.0526, Val Loss: 0.0525 | Train IoU: 0.7192, Val IoU: 0.7209 | Train Acc: 0.9857, Val Acc: 0.9863 | Train Precision: 0.8572, Val Precision: 0.8530 | Train Recall: 0.8189, Val Recall: 0.8233 | Train Dice: 0.8364, Val Dice: 0.8375
# Epoch 65/100 | Train Loss: 0.0509, Val Loss: 0.0509 | Train IoU: 0.7294, Val IoU: 0.7187 | Train Acc: 0.9862, Val Acc: 0.9864 | Train Precision: 0.8611, Val Precision: 0.8670 | Train Recall: 0.8271, Val Recall: 0.8078 | Train Dice: 0.8432, Val Dice: 0.8360
# Epoch 66/100 | Train Loss: 0.0518, Val Loss: 0.0529 | Train IoU: 0.7169, Val IoU: 0.6993 | Train Acc: 0.9856, Val Acc: 0.9844 | Train Precision: 0.8573, Val Precision: 0.8096 | Train Recall: 0.8150, Val Recall: 0.8372 | Train Dice: 0.8345, Val Dice: 0.8227
# Epoch 67/100 | Train Loss: 0.0514, Val Loss: 0.0510 | Train IoU: 0.7181, Val IoU: 0.7212 | Train Acc: 0.9855, Val Acc: 0.9863 | Train Precision: 0.8541, Val Precision: 0.8565 | Train Recall: 0.8199, Val Recall: 0.8209 | Train Dice: 0.8357, Val Dice: 0.8377
# Epoch 68/100 | Train Loss: 0.0494, Val Loss: 0.0513 | Train IoU: 0.7284, Val IoU: 0.7170 | Train Acc: 0.9862, Val Acc: 0.9860 | Train Precision: 0.8626, Val Precision: 0.8413 | Train Recall: 0.8240, Val Recall: 0.8293 | Train Dice: 0.8425, Val Dice: 0.8349
# Epoch 69/100 | Train Loss: 0.0487, Val Loss: 0.0471 | Train IoU: 0.7312, Val IoU: 0.7275 | Train Acc: 0.9862, Val Acc: 0.9866 | Train Precision: 0.8690, Val Precision: 0.8522 | Train Recall: 0.8224, Val Recall: 0.8322 | Train Dice: 0.8444, Val Dice: 0.8419
# Epoch 70/100 | Train Loss: 0.0508, Val Loss: 0.0517 | Train IoU: 0.7160, Val IoU: 0.6929 | Train Acc: 0.9852, Val Acc: 0.9850 | Train Precision: 0.8543, Val Precision: 0.8485 | Train Recall: 0.8180, Val Recall: 0.7909 | Train Dice: 0.8341, Val Dice: 0.8182
# Epoch 71/100 | Train Loss: 0.0490, Val Loss: 0.0461 | Train IoU: 0.7225, Val IoU: 0.7254 | Train Acc: 0.9858, Val Acc: 0.9869 | Train Precision: 0.8611, Val Precision: 0.8832 | Train Recall: 0.8202, Val Recall: 0.8028 | Train Dice: 0.8385, Val Dice: 0.8405
# Epoch 72/100 | Train Loss: 0.0470, Val Loss: 0.0472 | Train IoU: 0.7328, Val IoU: 0.7311 | Train Acc: 0.9864, Val Acc: 0.9866 | Train Precision: 0.8626, Val Precision: 0.8399 | Train Recall: 0.8303, Val Recall: 0.8496 | Train Dice: 0.8456, Val Dice: 0.8444
# Epoch 73/100 | Train Loss: 0.0464, Val Loss: 0.0476 | Train IoU: 0.7381, Val IoU: 0.7103 | Train Acc: 0.9865, Val Acc: 0.9864 | Train Precision: 0.8650, Val Precision: 0.8853 | Train Recall: 0.8353, Val Recall: 0.7822 | Train Dice: 0.8492, Val Dice: 0.8302
# Epoch 74/100 | Train Loss: 0.0458, Val Loss: 0.0489 | Train IoU: 0.7374, Val IoU: 0.6946 | Train Acc: 0.9867, Val Acc: 0.9857 | Train Precision: 0.8711, Val Precision: 0.8859 | Train Recall: 0.8285, Val Recall: 0.7628 | Train Dice: 0.8486, Val Dice: 0.8194
# Epoch 75/100 | Train Loss: 0.0454, Val Loss: 0.0453 | Train IoU: 0.7401, Val IoU: 0.7231 | Train Acc: 0.9866, Val Acc: 0.9869 | Train Precision: 0.8678, Val Precision: 0.8801 | Train Recall: 0.8347, Val Recall: 0.8018 | Train Dice: 0.8504, Val Dice: 0.8389
# Epoch 76/100 | Train Loss: 0.0446, Val Loss: 0.0470 | Train IoU: 0.7401, Val IoU: 0.7161 | Train Acc: 0.9868, Val Acc: 0.9863 | Train Precision: 0.8699, Val Precision: 0.8748 | Train Recall: 0.8326, Val Recall: 0.7977 | Train Dice: 0.8504, Val Dice: 0.8342
# Epoch 77/100 | Train Loss: 0.0437, Val Loss: 0.0483 | Train IoU: 0.7460, Val IoU: 0.7051 | Train Acc: 0.9870, Val Acc: 0.9857 | Train Precision: 0.8704, Val Precision: 0.8593 | Train Recall: 0.8394, Val Recall: 0.7965 | Train Dice: 0.8542, Val Dice: 0.8266
# Epoch 78/100 | Train Loss: 0.0443, Val Loss: 0.0482 | Train IoU: 0.7390, Val IoU: 0.7087 | Train Acc: 0.9866, Val Acc: 0.9855 | Train Precision: 0.8703, Val Precision: 0.8270 | Train Recall: 0.8314, Val Recall: 0.8317 | Train Dice: 0.8497, Val Dice: 0.8292
# Epoch 79/100 | Train Loss: 0.0440, Val Loss: 0.0450 | Train IoU: 0.7374, Val IoU: 0.7160 | Train Acc: 0.9867, Val Acc: 0.9860 | Train Precision: 0.8674, Val Precision: 0.8490 | Train Recall: 0.8318, Val Recall: 0.8202 | Train Dice: 0.8485, Val Dice: 0.8341
# Epoch 80/100 | Train Loss: 0.0431, Val Loss: 0.0438 | Train IoU: 0.7462, Val IoU: 0.7292 | Train Acc: 0.9869, Val Acc: 0.9869 | Train Precision: 0.8717, Val Precision: 0.8648 | Train Recall: 0.8393, Val Recall: 0.8229 | Train Dice: 0.8546, Val Dice: 0.8431
# Epoch 81/100 | Train Loss: 0.0426, Val Loss: 0.0443 | Train IoU: 0.7439, Val IoU: 0.7251 | Train Acc: 0.9870, Val Acc: 0.9869 | Train Precision: 0.8720, Val Precision: 0.8748 | Train Recall: 0.8360, Val Recall: 0.8088 | Train Dice: 0.8530, Val Dice: 0.8403
# Epoch 82/100 | Train Loss: 0.0433, Val Loss: 0.0466 | Train IoU: 0.7368, Val IoU: 0.7206 | Train Acc: 0.9867, Val Acc: 0.9857 | Train Precision: 0.8684, Val Precision: 0.8181 | Train Recall: 0.8301, Val Recall: 0.8577 | Train Dice: 0.8481, Val Dice: 0.8373
# Epoch 83/100 | Train Loss: 0.0438, Val Loss: 0.0454 | Train IoU: 0.7357, Val IoU: 0.7134 | Train Acc: 0.9864, Val Acc: 0.9863 | Train Precision: 0.8647, Val Precision: 0.8628 | Train Recall: 0.8336, Val Recall: 0.8043 | Train Dice: 0.8475, Val Dice: 0.8323
# Epoch 84/100 | Train Loss: 0.0422, Val Loss: 0.0438 | Train IoU: 0.7421, Val IoU: 0.7251 | Train Acc: 0.9869, Val Acc: 0.9867 | Train Precision: 0.8738, Val Precision: 0.8701 | Train Recall: 0.8322, Val Recall: 0.8133 | Train Dice: 0.8518, Val Dice: 0.8403
# Epoch 85/100 | Train Loss: 0.0409, Val Loss: 0.0428 | Train IoU: 0.7497, Val IoU: 0.7272 | Train Acc: 0.9873, Val Acc: 0.9868 | Train Precision: 0.8755, Val Precision: 0.8665 | Train Recall: 0.8394, Val Recall: 0.8189 | Train Dice: 0.8567, Val Dice: 0.8418
# Epoch 86/100 | Train Loss: 0.0412, Val Loss: 0.0442 | Train IoU: 0.7432, Val IoU: 0.7103 | Train Acc: 0.9870, Val Acc: 0.9864 | Train Precision: 0.8704, Val Precision: 0.8804 | Train Recall: 0.8370, Val Recall: 0.7861 | Train Dice: 0.8522, Val Dice: 0.8302
# Epoch 87/100 | Train Loss: 0.0420, Val Loss: 0.0422 | Train IoU: 0.7368, Val IoU: 0.7307 | Train Acc: 0.9867, Val Acc: 0.9869 | Train Precision: 0.8690, Val Precision: 0.8548 | Train Recall: 0.8296, Val Recall: 0.8340 | Train Dice: 0.8480, Val Dice: 0.8441
# Epoch 88/100 | Train Loss: 0.0408, Val Loss: 0.0457 | Train IoU: 0.7453, Val IoU: 0.6944 | Train Acc: 0.9870, Val Acc: 0.9858 | Train Precision: 0.8685, Val Precision: 0.8994 | Train Recall: 0.8412, Val Recall: 0.7523 | Train Dice: 0.8538, Val Dice: 0.8190
# Epoch 89/100 | Train Loss: 0.0410, Val Loss: 0.0444 | Train IoU: 0.7411, Val IoU: 0.7100 | Train Acc: 0.9869, Val Acc: 0.9863 | Train Precision: 0.8728, Val Precision: 0.8871 | Train Recall: 0.8329, Val Recall: 0.7806 | Train Dice: 0.8511, Val Dice: 0.8299
# Epoch 90/100 | Train Loss: 0.0404, Val Loss: 0.0435 | Train IoU: 0.7441, Val IoU: 0.7222 | Train Acc: 0.9871, Val Acc: 0.9867 | Train Precision: 0.8756, Val Precision: 0.8819 | Train Recall: 0.8331, Val Recall: 0.7994 | Train Dice: 0.8530, Val Dice: 0.8383
# Epoch 91/100 | Train Loss: 0.0400, Val Loss: 0.0424 | Train IoU: 0.7461, Val IoU: 0.7246 | Train Acc: 0.9871, Val Acc: 0.9866 | Train Precision: 0.8692, Val Precision: 0.8497 | Train Recall: 0.8412, Val Recall: 0.8307 | Train Dice: 0.8542, Val Dice: 0.8399
# Epoch 92/100 | Train Loss: 0.0386, Val Loss: 0.0419 | Train IoU: 0.7567, Val IoU: 0.7196 | Train Acc: 0.9876, Val Acc: 0.9866 | Train Precision: 0.8800, Val Precision: 0.8739 | Train Recall: 0.8443, Val Recall: 0.8026 | Train Dice: 0.8614, Val Dice: 0.8365
# Epoch 93/100 | Train Loss: 0.0384, Val Loss: 0.0438 | Train IoU: 0.7561, Val IoU: 0.7108 | Train Acc: 0.9875, Val Acc: 0.9859 | Train Precision: 0.8771, Val Precision: 0.8387 | Train Recall: 0.8459, Val Recall: 0.8232 | Train Dice: 0.8609, Val Dice: 0.8306
# Epoch 94/100 | Train Loss: 0.0380, Val Loss: 0.0428 | Train IoU: 0.7575, Val IoU: 0.7096 | Train Acc: 0.9876, Val Acc: 0.9865 | Train Precision: 0.8799, Val Precision: 0.9022 | Train Recall: 0.8454, Val Recall: 0.7686 | Train Dice: 0.8619, Val Dice: 0.8296
# Epoch 95/100 | Train Loss: 0.0375, Val Loss: 0.0395 | Train IoU: 0.7602, Val IoU: 0.7368 | Train Acc: 0.9878, Val Acc: 0.9873 | Train Precision: 0.8811, Val Precision: 0.8740 | Train Recall: 0.8478, Val Recall: 0.8243 | Train Dice: 0.8637, Val Dice: 0.8482
# Epoch 96/100 | Train Loss: 0.0376, Val Loss: 0.0406 | Train IoU: 0.7563, Val IoU: 0.7319 | Train Acc: 0.9877, Val Acc: 0.9870 | Train Precision: 0.8787, Val Precision: 0.8616 | Train Recall: 0.8451, Val Recall: 0.8290 | Train Dice: 0.8611, Val Dice: 0.8448
# Epoch 97/100 | Train Loss: 0.0378, Val Loss: 0.0418 | Train IoU: 0.7546, Val IoU: 0.7283 | Train Acc: 0.9876, Val Acc: 0.9864 | Train Precision: 0.8747, Val Precision: 0.8411 | Train Recall: 0.8464, Val Recall: 0.8440 | Train Dice: 0.8599, Val Dice: 0.8424
# Epoch 98/100 | Train Loss: 0.0368, Val Loss: 0.0392 | Train IoU: 0.7591, Val IoU: 0.7276 | Train Acc: 0.9878, Val Acc: 0.9871 | Train Precision: 0.8790, Val Precision: 0.8845 | Train Recall: 0.8483, Val Recall: 0.8037 | Train Dice: 0.8628, Val Dice: 0.8420
# Epoch 99/100 | Train Loss: 0.0362, Val Loss: 0.0397 | Train IoU: 0.7613, Val IoU: 0.7348 | Train Acc: 0.9880, Val Acc: 0.9869 | Train Precision: 0.8844, Val Precision: 0.8418 | Train Recall: 0.8459, Val Recall: 0.8524 | Train Dice: 0.8643, Val Dice: 0.8469
# Epoch 100/100 | Train Loss: 0.0367, Val Loss: 0.0453 | Train IoU: 0.7571, Val IoU: 0.6917 | Train Acc: 0.9877, Val Acc: 0.9855 | Train Precision: 0.8743, Val Precision: 0.8838 | Train Recall: 0.8508, Val Recall: 0.7602 | Train Dice: 0.8615, Val Dice: 0.8171

# %%
def test_model(model, test_loader, criterion, device='cuda'):
    model.eval()
    running_test_loss = 0.0
    test_iou_sum = 0
    test_acc_sum = 0
    test_precision_sum = 0
    test_recall_sum = 0
    test_dice_sum = 0
    test_samples = 0

    with torch.no_grad():
        for inputs1, inputs2, labels in test_loader:  # Change: Accept two input images
            inputs1, inputs2, labels = inputs1.to(device), inputs2.to(device), labels.to(device)

            # Forward pass with two inputs
            outputs = model(inputs1, inputs2)
            loss = criterion(outputs, labels)

            running_test_loss += loss.item() * inputs1.size(0)

            # Calculate metrics
            acc, precision, recall, dice, iou = calculate_metrics(outputs, labels)
            test_acc_sum += acc * inputs1.size(0)
            test_precision_sum += precision * inputs1.size(0)
            test_recall_sum += recall * inputs1.size(0)
            test_dice_sum += dice * inputs1.size(0)
            test_iou_sum += iou * inputs1.size(0)
            test_samples += inputs1.size(0)

    # Compute average metrics for the epoch
    epoch_test_loss = running_test_loss / test_samples
    epoch_test_iou = test_iou_sum / test_samples
    epoch_test_acc = test_acc_sum / test_samples
    epoch_test_precision = test_precision_sum / test_samples
    epoch_test_recall = test_recall_sum / test_samples
    epoch_test_dice = test_dice_sum / test_samples

    print(f'Test Loss: {epoch_test_loss:.4f} | '
          f'Test IoU: {epoch_test_iou:.4f} | '
          f'Test Acc: {epoch_test_acc:.4f} | '
          f'Test Precision: {epoch_test_precision:.4f} | '
          f'Test Recall: {epoch_test_recall:.4f} | '
          f'Test Dice: {epoch_test_dice:.4f}')

    # return {
    #     'loss': epoch_test_loss,
    #     'iou': epoch_test_iou,
    #     'accuracy': epoch_test_acc,
    #     'precision': epoch_test_precision,
    #     'recall': epoch_test_recall,
    #     'dice': epoch_test_dice
    # }

# Evaluate the model on the test set
test_results = test_model(model, LEVIR_test_loader, criterion, device=device)
# Out:
# Test Loss: 0.0490 | Test IoU: 0.7121 | Test Acc: 0.9832 | Test Precision: 0.8847 | Test Recall: 0.7846 | Test Dice: 0.8312

# %%
import matplotlib.pyplot as plt
import torch
import numpy as np
import random

# Set the seed for reproducibility
def set_seed(seed):
    torch.manual_seed(seed)               # PyTorch random seed
    np.random.seed(seed)                  # NumPy random seed
    random.seed(seed)                     # Python random seed
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)  # Set seed for all GPUs (if using CUDA)

# Set the seed value (choose any integer)
set_seed(42)

# Set up the figure size and the number of subplots
plt.figure(figsize=(15, 15))  # Adjust the figure size for larger plots

# Loop over 5 images from the LEVIR-CD test dataset
for i in range(5):
    # Get image pair and mask from LEVIR-CD test dataset
    image1, image2, mask = LEVIR_test_dataset[i]  # Assuming dataset returns tuple (image1, image2, mask)

    # Add batch dimension and move to device
    image1, image2, mask = image1.unsqueeze(dim=0), image2.unsqueeze(dim=0), mask.unsqueeze(dim=0)
    image1, image2, mask = image1.to(device), image2.to(device), mask.to(device)

    # Get model prediction (for Siamese U-Net, the model expects two inputs)
    prediction = model(image1, image2)
    prediction = (prediction > 0.5).float()  # Threshold to create binary mask

    # Detach the prediction from the graph and move it to the CPU for visualization
    image1 = image1.squeeze().detach().cpu()
    image2 = image2.squeeze().detach().cpu()
    prediction = prediction.squeeze().detach().cpu()
    mask = mask.squeeze().detach().cpu()

    # Print the shapes and unique values for debugging
    print(f"Prediction shape: {prediction.shape}")
    print(f"Mask shape: {mask.shape}")
    print(f"Image1 shape: {image1.shape}")
    print(f"Image2 shape: {image2.shape}")
    print(f"Unique prediction values: {torch.unique(prediction)}")

    # Plot the first input image (Image1)
    plt.subplot(5, 4, 4*i + 1)
    plt.imshow(image1.permute(1, 2, 0))
    plt.axis('off')
    plt.title(f"Pre-Change {i+1}")

    # Plot the second input image (Image2)
    plt.subplot(5, 4, 4*i + 2)
    plt.imshow(image2.permute(1, 2, 0))
    plt.axis('off')
    plt.title(f"Post Change {i+1}")

    # Plot the predicted segmentation mask
    plt.subplot(5, 4, 4*i + 3)
    plt.imshow(prediction, cmap='gray')
    plt.axis('off')
    plt.title(f"Predicted {i+1}")

    # Plot the ground truth mask
    plt.subplot(5, 4, 4*i + 4)
    plt.imshow(mask, cmap='gray')
    plt.axis('off')
    plt.title(f"Ground Truth {i+1}")

# Adjust the layout and spacing
plt.tight_layout()

# Save the figure as an image file (e.g., PNG)
plt.savefig('Siamese_UNet_with_LEVIR_CD_2.png', bbox_inches='tight')  # Use bbox_inches='tight' to save without extra whitespace

# Show the figure
plt.show()
# Out:
# Prediction shape: torch.Size([256, 256])
# Mask shape: torch.Size([256, 256])
# Image1 shape: torch.Size([3, 256, 256])
# Image2 shape: torch.Size([3, 256, 256])
# Unique prediction values: tensor([0., 1.])
# Prediction shape: torch.Size([256, 256])
# Mask shape: torch.Size([256, 256])
# Image1 shape: torch.Size([3, 256, 256])
# Image2 shape: torch.Size([3, 256, 256])
# Unique prediction values: tensor([0., 1.])
# Prediction shape: torch.Size([256, 256])
# Mask shape: torch.Size([256, 256])
# Image1 shape: torch.Size([3, 256, 256])
# Image2 shape: torch.Size([3, 256, 256])
# Unique prediction values: tensor([0., 1.])
# Prediction shape: torch.Size([256, 256])
# Mask shape: torch.Size([256, 256])
# Image1 shape: torch.Size([3, 256, 256])
# Image2 shape: torch.Size([3, 256, 256])
# Unique prediction values: tensor([0., 1.])
# Prediction shape: torch.Size([256, 256])
# Mask shape: torch.Size([256, 256])
# Image1 shape: torch.Size([3, 256, 256])
# Image2 shape: torch.Size([3, 256, 256])
# Unique prediction values: tensor([0., 1.])

# %%
class DecoderBlock(nn.Module):
    def __init__(self, in_channels, skip_channels, out_channels):
        super(DecoderBlock, self).__init__()
        self.upconv = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=2, stride=2)
        # conv1 input = upconv output channels + skip connection channels
        self.conv1 = ConvBlock(out_channels + skip_channels, out_channels)
        self.conv2 = ConvBlock(out_channels, out_channels)

    def forward(self, x, skip):
        x = self.upconv(x)
        # If channel mismatch occurs due to concatenation, reduce skip channels using 1x1 conv
        if x.shape[2:] != skip.shape[2:]:
            skip = F.interpolate(skip, size=x.shape[2:], mode='bilinear', align_corners=False)
        x = torch.cat([x, skip], dim=1)
        x = self.conv1(x)
        x = self.conv2(x)
        return x

# =========================================
# Hybrid Siamese UNet fixed
# =========================================
class HybridSiameseUNet(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(HybridSiameseUNet, self).__init__()

        # --- Encoders ---
        self.encoder1a = EncoderBlock(in_channels, 64)
        self.encoder2a = EncoderBlock(64, 128)
        self.encoder3a = EncoderBlock(128, 256)
        self.encoder4a = EncoderBlock(256, 512)

        self.encoder1b = EncoderBlock(in_channels, 64)
        self.encoder2b = EncoderBlock(64, 128)
        self.encoder3b = EncoderBlock(128, 256)
        self.encoder4b = EncoderBlock(256, 512)

        # Bottleneck
        self.bottleneck = ConvBlock(1024, 1024)

        # --- Decoder ---
        self.decoder4 = DecoderBlock(1024, 1024, 512)  # skip = concat_e4 channels = 512+512=1024
        self.decoder3 = DecoderBlock(512, 512, 256)    # skip = concat_e3 channels = 256+256=512
        self.decoder2 = DecoderBlock(256, 256, 128)    # skip = concat_e2 channels = 128+128=256
        self.decoder1 = DecoderBlock(128, 128, 64)     # skip = concat_e1 channels = 64+64=128

        # Hybrid addition
        self.hybrid_conv1 = ConvBlock(64, 32)
        self.hybrid_conv2 = ConvBlock(32, 16)

        # Final output
        self.final_conv = nn.Conv2d(16, out_channels, kernel_size=1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x1, x2):
        # --- Encoder ---
        e1a, p1a = self.encoder1a(x1)
        e2a, p2a = self.encoder2a(p1a)
        e3a, p3a = self.encoder3a(p2a)
        e4a, p4a = self.encoder4a(p3a)

        e1b, p1b = self.encoder1b(x2)
        e2b, p2b = self.encoder2b(p1b)
        e3b, p3b = self.encoder3b(p2b)
        e4b, p4b = self.encoder4b(p3b)

        # --- Concatenate skip connections ---
        concat_e4 = torch.cat([e4a, e4b], dim=1)  # 512+512=1024
        concat_e3 = torch.cat([e3a, e3b], dim=1)  # 256+256=512
        concat_e2 = torch.cat([e2a, e2b], dim=1)  # 128+128=256
        concat_e1 = torch.cat([e1a, e1b], dim=1)  # 64+64=128

        # --- Bottleneck ---
        b = self.bottleneck(torch.cat([p4a, p4b], dim=1))  # 512+512=1024

        # --- Decoder ---
        d4 = self.decoder4(b, concat_e4)
        d3 = self.decoder3(d4, concat_e3)
        d2 = self.decoder2(d3, concat_e2)
        d1 = self.decoder1(d2, concat_e1)

        # --- Hybrid ---
        h = self.hybrid_conv1(d1)
        h = self.hybrid_conv2(h)

        out = self.sigmoid(self.final_conv(h))
        return out

# Example
x1 = torch.randn(1,3,256,256)
x2 = torch.randn(1,3,256,256)
model = HybridSiameseUNet(3,1)
output = model(x1,x2)
print("Output shape:", output.shape)
# Out:
# Output shape: torch.Size([1, 1, 256, 256])

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# =========================================
# Metrics calculation
# =========================================
def calculate_metrics(outputs, labels, threshold=0.5):
    predictions = (outputs > threshold).float()
    labels = labels.float()

    tp = torch.sum(predictions * labels)
    tn = torch.sum((1 - predictions) * (1 - labels))
    fp = torch.sum(predictions * (1 - labels))
    fn = torch.sum((1 - predictions) * labels)

    precision = tp / (tp + fp + 1e-6)
    recall = tp / (tp + fn + 1e-6)
    dice = 2 * tp / (2 * tp + fp + fn + 1e-6)
    iou = tp / (tp + fp + fn + 1e-6)
    accuracy = (tp + tn) / (tp + tn + fp + fn + 1e-6)

    return accuracy.item(), precision.item(), recall.item(), dice.item(), iou.item(), predictions

# =========================================
# Training Loop with history
# =========================================
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=60, device='cuda'):
    model.to(device)
    history = {
        'train_loss':[], 'val_loss':[],
        'train_iou':[], 'val_iou':[],
        'train_acc':[], 'val_acc':[],
        'train_precision':[], 'val_precision':[],
        'train_recall':[], 'val_recall':[],
        'train_dice':[], 'val_dice':[]
    }

    all_val_labels = []
    all_val_preds = []

    for epoch in range(num_epochs):
        model.train()
        running_train_loss = 0.0
        train_iou_sum = train_acc_sum = train_precision_sum = train_recall_sum = train_dice_sum = 0
        train_samples = 0

        for inputs1, inputs2, labels in train_loader:
            inputs1, inputs2, labels = inputs1.to(device), inputs2.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs1, inputs2)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_train_loss += loss.item() * inputs1.size(0)
            acc, precision, recall, dice, iou, _ = calculate_metrics(outputs, labels)
            train_acc_sum += acc * inputs1.size(0)
            train_precision_sum += precision * inputs1.size(0)
            train_recall_sum += recall * inputs1.size(0)
            train_dice_sum += dice * inputs1.size(0)
            train_iou_sum += iou * inputs1.size(0)
            train_samples += inputs1.size(0)

        epoch_train_loss = running_train_loss / train_samples
        epoch_train_iou = train_iou_sum / train_samples
        epoch_train_acc = train_acc_sum / train_samples
        epoch_train_precision = train_precision_sum / train_samples
        epoch_train_recall = train_recall_sum / train_samples
        epoch_train_dice = train_dice_sum / train_samples

        # Validation
        model.eval()
        running_val_loss = 0.0
        val_iou_sum = val_acc_sum = val_precision_sum = val_recall_sum = val_dice_sum = 0
        val_samples = 0
        all_val_labels.clear()
        all_val_preds.clear()

        with torch.no_grad():
            for inputs1, inputs2, labels in val_loader:
                inputs1, inputs2, labels = inputs1.to(device), inputs2.to(device), labels.to(device)
                outputs = model(inputs1, inputs2)
                loss = criterion(outputs, labels)
                running_val_loss += loss.item() * inputs1.size(0)

                acc, precision, recall, dice, iou, preds = calculate_metrics(outputs, labels)
                val_acc_sum += acc * inputs1.size(0)
                val_precision_sum += precision * inputs1.size(0)
                val_recall_sum += recall * inputs1.size(0)
                val_dice_sum += dice * inputs1.size(0)
                val_iou_sum += iou * inputs1.size(0)
                val_samples += inputs1.size(0)

                all_val_labels.append(labels.cpu().numpy().flatten())
                all_val_preds.append(preds.cpu().numpy().flatten())

        epoch_val_loss = running_val_loss / val_samples
        epoch_val_iou = val_iou_sum / val_samples
        epoch_val_acc = val_acc_sum / val_samples
        epoch_val_precision = val_precision_sum / val_samples
        epoch_val_recall = val_recall_sum / val_samples
        epoch_val_dice = val_dice_sum / val_samples

        # Save metrics history for plotting
        history['train_loss'].append(epoch_train_loss)
        history['val_loss'].append(epoch_val_loss)
        history['train_iou'].append(epoch_train_iou)
        history['val_iou'].append(epoch_val_iou)
        history['train_acc'].append(epoch_train_acc)
        history['val_acc'].append(epoch_val_acc)
        history['train_precision'].append(epoch_train_precision)
        history['val_precision'].append(epoch_val_precision)
        history['train_recall'].append(epoch_train_recall)
        history['val_recall'].append(epoch_val_recall)
        history['train_dice'].append(epoch_train_dice)
        history['val_dice'].append(epoch_val_dice)

        print(f'Epoch {epoch+1}/{num_epochs} | '
              f'Train Loss: {epoch_train_loss:.4f}, Val Loss: {epoch_val_loss:.4f} | '
              f'Train IoU: {epoch_train_iou:.4f}, Val IoU: {epoch_val_iou:.4f} | '
              f'Train Acc: {epoch_train_acc:.4f}, Val Acc: {epoch_val_acc:.4f} | '
              f'Train Precision: {epoch_train_precision:.4f}, Val Precision: {epoch_val_precision:.4f} | '
              f'Train Recall: {epoch_train_recall:.4f}, Val Recall: {epoch_val_recall:.4f} | '
              f'Train Dice: {epoch_train_dice:.4f}, Val Dice: {epoch_val_dice:.4f}')

    # Save model
    torch.save(model.state_dict(), 'hybrid_siamese_unet.pt')

    # Confusion Matrix & Classification Report
    all_val_labels = np.concatenate(all_val_labels)
    all_val_preds = np.concatenate(all_val_preds)
    cm = confusion_matrix(all_val_labels, all_val_preds)
    cr = classification_report(all_val_labels, all_val_preds, digits=4)

    print("\n=== Confusion Matrix ===\n", cm)
    print("\n=== Classification Report ===\n", cr)

    # Plot curves
    plt.figure(figsize=(15,6))
    plt.subplot(1,2,1)
    plt.plot(history['train_loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.title("Loss Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(history['train_iou'], label='Train IoU')
    plt.plot(history['val_iou'], label='Val IoU')
    plt.title("IoU Curve")
    plt.xlabel("Epoch")
    plt.ylabel("IoU")
    plt.legend()
    plt.show()

    return model, history

# =========================================
# Usage
# =========================================
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = HybridSiameseUNet(in_channels=3, out_channels=1).to(device)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

trained_model, history = train_model(model, LEVIR_train_loader, LEVIR_val_loader, criterion, optimizer, num_epochs=100, device=device)
# Out:
# Epoch 1/100 | Train Loss: 0.5499, Val Loss: 0.4855 | Train IoU: 0.1832, Val IoU: 0.0000 | Train Acc: 0.8544, Val Acc: 0.9580 | Train Precision: 0.2030, Val Precision: 0.5000 | Train Recall: 0.6398, Val Recall: 0.0000 | Train Dice: 0.3023, Val Dice: 0.0000
